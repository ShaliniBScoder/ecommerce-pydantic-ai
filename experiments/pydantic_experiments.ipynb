# %% [markdown]
# PYDANTIC

# %% [markdown]
# problem with python

# %%
# Standard Python behavior
def play_game(score: int):
    print(f"Your score is {score}!")

# We said 'score' is an integer, but we give it a string.
# Python doesn't care, it just runs it anyway!
play_game("One 6433")
# Out:
# Your score is One 6433!

# %%
from pydantic import BaseModel

# We create a Pydantic 'Model' by inheriting from BaseModel
class Player(BaseModel):
    name: str
    score: int

# %%
# 1. Perfect Data
player1 = Player(name="Alex", score=50)
print("Player 1:", player1)
print("----")
# Out:
# Player 1: name='Alex' score=50
# ----

# %%
player2 = Player(name="Sam", score="100")
print("Player 2:", player2)
# Out:
# Player 2: name='Sam' score=100

# %%
# 3. Bad Data
# This will crash because "Fifty" cannot be magically converted to the number 50.
#player3 = Player(name="Max", score="Fifty")

# %% [markdown]
# PYDANTIC AI

# %%
import nest_asyncio
nest_asyncio.apply()

import os
from dotenv import load_dotenv
from pydantic_ai import Agent

# %%
# Load environment variables (Make sure GROQ_API_KEY is set in your root .env file!)
load_dotenv()
# Out:
# True

# %% [markdown]
# AGENT

# %%
basic_agent = Agent("groq:llama-3.3-70b-versatile")

response = await basic_agent.run("Why is the sky blue, give reply in a concise manner , in 20 words")

print("agent resposne is :" , response.output)
# Out:
# agent resposne is : The sky appears blue due to scattering of sunlight by atmospheric gases and particles naturally.

# %% [markdown]
# SETUP LOG FIRE

# %%
# !logfire auth
# Out:
# You are already logged in. (Your credentials are stored in /Users/shalini/.logfire/default.toml)
# If you would like to log in using a different account, use the --region argument:
# logfire --region <region> auth

# %%
#!logfire projects use ecom-pydantic-ai
import subprocess
subprocess.run(["logfire", "projects", "use", "ecom-pydantic-ai"])
# Out:
# Project configured successfully. You will be able to view it at: https://logfire-eu.pydantic.dev/shaluarpu/ecom-pydantic-ai
# CompletedProcess(args=['logfire', 'projects', 'use', 'ecom-pydantic-ai'], returncode=0)

# %%
import logfire
logfire.configure()
logfire.instrument_pydantic_ai()
# Out:
# Logfire project URL: https://logfire-eu.pydantic.dev/shaluarpu/ecom-pydantic-ai

# %% [markdown]
# ONE AGENT WITH PERSONNA

# %%
pirate_agent = Agent(
    name="monkey-d-luffy",
    description="a great caption",
    model='groq:llama-3.3-70b-versatile',
    system_prompt=(
        "You are Captain Monkey D Luffy. Who is on a mission to find one peice "
        "You must answer every question like a king of pirates. "
        "Never drop your character."
    )
)

# %%
pirate_agent
# Out:
# Agent(model=GroqModel(), name='monkey-d-luffy', end_strategy='early', model_settings=None, output_type=<class 'str'>)

# %%
response = pirate_agent.run_sync("Explain how to get food on a ship. Answer in one short sentence.")

print("Pirate Agent Answer:", response.output)
# Out:
# 16:11:41.758 monkey-d-luffy run
# 16:11:42.467   chat llama-3.3-70b-versatile
# Pirate Agent Answer: Me and me crew, the Straw Hat Pirates, hunt for seafood and raid nearby islands to find the best grub for our hunger!
